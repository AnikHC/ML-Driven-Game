# %%
import tf2onnx
import tensorflow as tf

# %%
model = tf.keras.models.load_model("best_classifier.h5")

# %%
onnx_model, _=tf2onnx.convert.from_keras(model)

# %%
with open("action_classifier.onnx", "wb") as f:
    f.write(onnx_model.SerializeToString())
